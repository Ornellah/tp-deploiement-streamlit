# %% [markdown]
# # TP - Déploiement d'application
#
# Dans ce TP vous serez amené à développer un dashboard avec streamlit dans l'objectif de le mettre en ligne.
#
# Ce notebook vous servira à tester vos graphiques avant de les intégrer à l'application streamlit contenue dans le fichier `app.py`.
#
# Le jeu de donnée à observer contient les informations de client ayant fait la demande d'un prêt (variable y). Les détails du jeu de données sont disponibles à cette **[addresse](https://www.kaggle.com/datasets/prakharrathi25/banking-dataset-marketing-targets)**.
#
# Le fichier `requirements.txt` contient les dépendances nécessaires du projet.
#
# <img src='https://cdn.analyticsvidhya.com/wp-content/uploads/2021/06/39595st.jpeg' width=600>
#
# [Streamlit](https://docs.streamlit.io/) est un framework Python simple et efficace pour créer rapidement des applications web interactives pour la data science.

# %%
import pandas as pd
import streamlit as st
import plotly.express as px 
import matplotlib
import seaborn


df = pd.read_csv('train.csv')
df.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  13829   29  technician   single   tertiary      no    18254      no   no
# 1  22677   26    services   single  secondary      no      512     yes  yes
# 2  10541   30  management   single  secondary      no      135      no   no
# 3  13689   41  technician  married    unknown      no       30     yes   no
# 4  11304   27      admin.   single  secondary      no      321      no  yes
#
#     contact  day month  campaign  pdays  previous poutcome   y
# 0  cellular   11   may         2     -1         0  unknown  no
# 1   unknown    5   jun         3     -1         0  unknown  no
# 2  cellular   14   aug         2     -1         0  unknown  no
# 3  cellular   10   jul         1     -1         0  unknown  no
# 4   unknown    2   sep         1     -1         0  unknown  no

# %%
fig = px.histogram(df, x="marital")
fig

# %%
fig = px.histogram(df.sort_values("age"), x="age")
fig

# %%
fig = px.pie(df.sort_values("job"), names=df["job"])
fig

# %%
fig = px.histogram(df, x="education")
fig

# %%
marital='Single'
education = 'tertiary'
age=18
agemax=60
test = df[df['marital'] == marital.lower()][df["education"] == education.lower()][df["age"]>=age][df["age"]<=agemax]
# Out:
# C:\Users\vosco\AppData\Local\Temp\ipykernel_2488\175337352.py:5: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\vosco\AppData\Local\Temp\ipykernel_2488\175337352.py:5: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\vosco\AppData\Local\Temp\ipykernel_2488\175337352.py:5: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
import plotly.graph_objects as go

fig = px.bar(test, x="y")
fig

# %%
fig = px.bar(test, x="y")
fig

# %%
housing="Yes"
loan="Yes"
test = df[df["housing"] == housing.lower()][df["loan"]==loan.lower()]
# Out:
# C:\Users\vosco\AppData\Local\Temp\ipykernel_2488\1061719655.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
test2 = test["age"].mean()
test2
# fig = px.bar(test2, x="age")
# fig
# Out:
# 39.01325757575758
